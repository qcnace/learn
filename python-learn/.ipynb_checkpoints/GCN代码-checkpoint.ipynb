# %%
import itertools
import os
import os.path as osp
import pickle
import urllib
from collections import namedtuple
import numpy as np
import scipy.sparse as sp
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#数据准备
Data=namedtuple('Data',['x','y','adjacency','train_mask','val_mask','test_mask'])
def tensor_from_numpy(x,device):
    return torch.from_numpy(x).to(device)
class CoraData(object):
    filenames=['ind.cora.{}'.format(name) for name in ['x','tx','allx','y','ty','ally','graph','test.index']]
    def __init__(self,data_root='data',rebuild=False):
        self.data_root=data_root
        save_file=osp.join(self.data_root,'ch5_cached.pkl')
        if osp.exists(save_file) and not rebuild:
            self._data=pickle.load(open(save_file,'rb'))
        else:
            self._data=self.process_data()
            with open(save_file,'wb') as f:
                pickle.dump(self.data,f)
    @property
    def data(self):
        return self._data
        
    def process_data(self):
        _,tx,allx,y,ty,ally,graph,test_index=[self.read_data(osp.join(self.data_root,name)) for name in self.filenames]
        train_index=np.arange(y.shape[0])
        val_index=np.arange(y.shape[0],y.shape[0]+500)
        sorted_test_index=sorted(test_index)
        x=np.concatenate((allx,tx),axis=0)
        y=np.concatenate((ally,ty),axis=0).argmax(axis=1)
        x[test_index]=x[sorted_test_index]
        y[test_index]=y[sorted_test_index]
        num_nodes=x.shape[0]
        train_mask=np.zeros(num_nodes,dtype=np.bool_)
        val_mask=np.zeros(num_nodes,dtype=np.bool_)
        test_mask=np.zeros(num_nodes,dtype=np.bool_)
        train_mask[train_index]=True
        val_mask[val_index]=True
        test_mask[test_index]=True
        adjacency=self.build_adjacency(graph)
        return Data(x=x,y=y,adjacency=adjacency,train_mask=train_mask,val_mask=val_mask,test_mask=test_mask)
    @staticmethod#类里面写一个函数
    def build_adjacency(adj_dict):
        edge_index=[]
        num_nodes=len(adj_dict)
        for src,dst in adj_dict.items():
            edge_index.extend([src,v] for v in dst)
            edge_index.extend([v,src] for v in dst)
        edge_index=list(k for k,_ in itertools.groupby(sorted(edge_index)))
        edge_index=np.asarray(edge_index)
        adjacency=sp.coo_matrix((np.ones(len(edge_index)),(edge_index[:,0],edge_index[:,1])),shape=(num_nodes,num_nodes),dtype='float32')
        return adjacency
    @staticmethod
    def read_data(path):
        name=osp.basename(path)
        if name=='ind.cora.test.index':
            out=np.genfromtxt(path,dtype='int64')
            return out
        else:
            out=pickle.load(open(path,'rb'),encoding='latin1')
            out=out.toarray() if hasattr(out,'toarray') else out
            return out
    @staticmethod 
    def normalization(adjacency):
        adjacency+=sp.eye(adjacency.shape[0])
        degree=np.array(adjacency.sum(1))
        d_hat=sp.diags(np.power(degree,-0.5).flatten())
        return d_hat.dot(adjacency).dot(d_hat).tocoo()

# %%
#图卷积层定义
class GraphConvolution(nn.Module):
    def __init__(self,input_dim,output_dim,use_bias=True):
        super(GraphConvolution,self).__init__()
        self.input_dim=input_dim
        self.output_dim=output_dim
        self.use_bias=use_bias
        self.weight=nn.Parameter(torch.Tensor(input_dim,output_dim))
        if self.use_bias:
            self.bias=nn.Parameter(torch.Tensor(output_dim))
        else:
            self.register_parameter('bias',None)
        self.reset_parameters()

    def reset_parameters(self):
        init.kaiming_uniform_(self.weight)
        if self.use_bias:
            init.zeros_(self.bias)
    def forward(self,adjacency,input_feature):
        support=torch.mm(input_feature,self.weight)
        output=torch.sparse.mm(adjacency,support)
        if self.use_bias:
            output+=self.bias
        return output
    def __repr__(self):
        return self.__class__.__name__+'('+str(self.input_dim)+'->'+str(self.output_dim)+')'

# %%
#模型定义
class GcnNet(nn.Module):
    def __init__(self,input_dim=1433):
        super(GcnNet,self).__init__()
        self.gcn1=GraphConvolution(input_dim,16)
        self.gcn2=GraphConvolution(16,7)
    def forward(self,adjacency,feature):
        h=F.relu(self.gcn1(adjacency,feature))
        logits=self.gcn2(adjacency,h)
        return logits

# %%
#模型训练
LEARNING_RATE=0.1
WEIGHT_DECAY=5e-4
EPOCHS=200
DEVICE='cuda' if torch.cuda.is_available() else 'cpu'

# %%
#加载数据，转换为torch.Tensor
dataset=CoraData().data
node_feature=dataset.x/dataset.x.sum(1,keepdims=True)
tensor_x=tensor_from_numpy(node_feature,DEVICE)
tensor_y=tensor_from_numpy(dataset.y,DEVICE)
tensor_train_mask=tensor_from_numpy(dataset.train_mask,DEVICE)
tensor_val_mask=tensor_from_numpy(dataset.val_mask,DEVICE)
tensor_test_mask=tensor_from_numpy(dataset.test_mask,DEVICE)
normalize_adjacency=CoraData.normalization(dataset.adjacency)
num_nodes,input_dim=node_feature.shape
indices=torch.from_numpy(np.asarray([normalize_adjacency.row,normalize_adjacency.col]).astype('int64')).long()
values=torch.from_numpy(normalize_adjacency.data.astype(np.float32))
tensor_adjacency=torch.sparse.FloatTensor(indices,values,(num_nodes,num_nodes)).to(DEVICE)

# %%
#模型定义
model=GcnNet(input_dim).to(DEVICE)
criterion=nn.CrossEntropyLoss().to(DEVICE)
optimizer=optim.Adam(model.parameters(),lr=LEARNING_RATE,weight_decay=WEIGHT_DECAY)

# %%
#训练函数
def train():
    loss_history=[]
    val_acc_history=[]
    model.train()
    train_y=tensor_y[tensor_train_mask]
    for epoch in range(EPOCHS):
        logits=model(tensor_adjacency,tensor_x)#前向传播
        train_mask_logits=logits[tensor_train_mask]
        loss=criterion(train_mask_logits,train_y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_acc,_,_=test(tensor_train_mask)
        val_acc,_,_=test(tensor_val_mask)
        loss_history.append(loss.item())
        val_acc_history.append(val_acc.item())
        print('epoch{:03d}:loss{:.4f},trainAcc{:.4f},ValAcc:{:.4f}'.format(epoch,loss.item(),train_acc.item(),val_acc.item()))
    return loss_history,val_acc_history

# %%
def test(mask):
    model.eval()
    with torch.no_grad():
        logits=model(tensor_adjacency,tensor_x)
        test_mask_logits=logits[mask]
        predict_y=test_mask_logits.max(1)[1]
        accuarcy=torch.eq(predict_y,tensor_y[mask]).float().mean()
    return accuarcy,test_mask_logits.cpu().numpy(),tensor_y[mask].cpu().numpy()

# %%
def plot_loss_with_acc(loss_history,val_acc_history):
    fig=plt.figure()
    ax1=fig.add_subplot(111)
    ax1.plot(range(len(loss_history)),loss_history,c=np.array([255,71,90])/255.)
    plt.ylabel('loss')

    ax2=fig.add_subplot(111,sharex=ax1,frameon=False)
    ax2.plot(range(len(val_acc_history)),val_acc_history,c=np.array([79,179,255])/255.)
    ax2.yaxis.set_tick_params(labelleft=False, labelright=True)
    ax2.yaxis.set_label_position('right')
    plt.ylabel('ValAcc')
    plt.xlabel('epoch')
    plt.title('training loss & validation accuracy')
    plt.show()

# %%
loss,val_acc=train()
test_acc,test_logits,test_label=test(tensor_test_mask)
print('test accuarcy',test_acc.item())
# Out:
# epoch000:loss1.9436,trainAcc0.3214,ValAcc:0.2000
# epoch001:loss1.8665,trainAcc0.4214,ValAcc:0.2000
# epoch002:loss1.7514,trainAcc0.7000,ValAcc:0.3380
# epoch003:loss1.5958,trainAcc0.7714,ValAcc:0.4240
# epoch004:loss1.4504,trainAcc0.8786,ValAcc:0.6520
# epoch005:loss1.2792,trainAcc0.9071,ValAcc:0.6980
# epoch006:loss1.1070,trainAcc0.9714,ValAcc:0.7080
# epoch007:loss0.9366,trainAcc0.9786,ValAcc:0.7640
# epoch008:loss0.7787,trainAcc0.9786,ValAcc:0.7820
# epoch009:loss0.6415,trainAcc0.9786,ValAcc:0.7820
# epoch010:loss0.5253,trainAcc0.9857,ValAcc:0.7880
# epoch011:loss0.4362,trainAcc0.9857,ValAcc:0.7820
# epoch012:loss0.3654,trainAcc0.9929,ValAcc:0.7860
# epoch013:loss0.3115,trainAcc0.9929,ValAcc:0.7840
# epoch014:loss0.2722,trainAcc0.9929,ValAcc:0.7880
# epoch015:loss0.2430,trainAcc0.9929,ValAcc:0.7880
# epoch016:loss0.2232,trainAcc0.9929,ValAcc:0.7980
# epoch017:loss0.2097,trainAcc0.9929,ValAcc:0.7920
# epoch018:loss0.2017,trainAcc0.9929,ValAcc:0.7940
# epoch019:loss0.1965,trainAcc1.0000,ValAcc:0.7880
# epoch020:loss0.1945,trainAcc1.0000,ValAcc:0.7940
# epoch021:loss0.1922,trainAcc1.0000,ValAcc:0.8020
# epoch022:loss0.1915,trainAcc1.0000,ValAcc:0.7900
# epoch023:loss0.1881,trainAcc1.0000,ValAcc:0.7940
# epoch024:loss0.1854,trainAcc1.0000,ValAcc:0.7900
# epoch025:loss0.1797,trainAcc1.0000,ValAcc:0.7940
# epoch026:loss0.1746,trainAcc1.0000,ValAcc:0.7860
# epoch027:loss0.1673,trainAcc1.0000,ValAcc:0.7920
# epoch028:loss0.1610,trainAcc1.0000,ValAcc:0.7860
# epoch029:loss0.1544,trainAcc1.0000,ValAcc:0.7860
# epoch030:loss0.1488,trainAcc1.0000,ValAcc:0.7860
# epoch031:loss0.1440,trainAcc1.0000,ValAcc:0.7860
# epoch032:loss0.1402,trainAcc1.0000,ValAcc:0.7860
# epoch033:loss0.1371,trainAcc1.0000,ValAcc:0.7840
# epoch034:loss0.1347,trainAcc1.0000,ValAcc:0.7880
# epoch035:loss0.1330,trainAcc1.0000,ValAcc:0.7880
# epoch036:loss0.1317,trainAcc1.0000,ValAcc:0.7900
# epoch037:loss0.1304,trainAcc1.0000,ValAcc:0.7880
# epoch038:loss0.1293,trainAcc1.0000,ValAcc:0.7880
# epoch039:loss0.1281,trainAcc1.0000,ValAcc:0.7880
# epoch040:loss0.1269,trainAcc1.0000,ValAcc:0.7880
# epoch041:loss0.1259,trainAcc1.0000,ValAcc:0.7880
# epoch042:loss0.1244,trainAcc1.0000,ValAcc:0.7900
# epoch043:loss0.1234,trainAcc1.0000,ValAcc:0.7880
# epoch044:loss0.1222,trainAcc1.0000,ValAcc:0.7900
# epoch045:loss0.1213,trainAcc1.0000,ValAcc:0.7900
# epoch046:loss0.1207,trainAcc1.0000,ValAcc:0.7900
# epoch047:loss0.1202,trainAcc1.0000,ValAcc:0.7880
# epoch048:loss0.1202,trainAcc1.0000,ValAcc:0.7900
# epoch049:loss0.1203,trainAcc1.0000,ValAcc:0.7920
# epoch050:loss0.1194,trainAcc1.0000,ValAcc:0.7920
# epoch051:loss0.1175,trainAcc1.0000,ValAcc:0.7900
# epoch052:loss0.1158,trainAcc1.0000,ValAcc:0.7920
# epoch053:loss0.1153,trainAcc1.0000,ValAcc:0.7900
# epoch054:loss0.1160,trainAcc1.0000,ValAcc:0.7900
# epoch055:loss0.1167,trainAcc1.0000,ValAcc:0.7900
# epoch056:loss0.1160,trainAcc1.0000,ValAcc:0.7880
# epoch057:loss0.1149,trainAcc1.0000,ValAcc:0.7940
# epoch058:loss0.1142,trainAcc1.0000,ValAcc:0.7960
# epoch059:loss0.1143,trainAcc1.0000,ValAcc:0.7900
# epoch060:loss0.1149,trainAcc1.0000,ValAcc:0.8040
# epoch061:loss0.1151,trainAcc1.0000,ValAcc:0.7900
# epoch062:loss0.1144,trainAcc1.0000,ValAcc:0.7940
# epoch063:loss0.1136,trainAcc1.0000,ValAcc:0.8000
# epoch064:loss0.1130,trainAcc1.0000,ValAcc:0.7920
# epoch065:loss0.1132,trainAcc1.0000,ValAcc:0.7960
# epoch066:loss0.1137,trainAcc1.0000,ValAcc:0.7900
# epoch067:loss0.1141,trainAcc1.0000,ValAcc:0.8020
# epoch068:loss0.1140,trainAcc1.0000,ValAcc:0.7880
# epoch069:loss0.1136,trainAcc1.0000,ValAcc:0.8060
# epoch070:loss0.1132,trainAcc1.0000,ValAcc:0.7980
# epoch071:loss0.1131,trainAcc1.0000,ValAcc:0.7960
# epoch072:loss0.1133,trainAcc1.0000,ValAcc:0.8000
# epoch073:loss0.1139,trainAcc1.0000,ValAcc:0.7940
# epoch074:loss0.1149,trainAcc1.0000,ValAcc:0.7920
# epoch075:loss0.1163,trainAcc1.0000,ValAcc:0.7960
# epoch076:loss0.1180,trainAcc1.0000,ValAcc:0.7840
# epoch077:loss0.1178,trainAcc1.0000,ValAcc:0.8020
# epoch078:loss0.1140,trainAcc1.0000,ValAcc:0.7860
# epoch079:loss0.1111,trainAcc1.0000,ValAcc:0.7900
# epoch080:loss0.1136,trainAcc1.0000,ValAcc:0.8020
# epoch081:loss0.1156,trainAcc1.0000,ValAcc:0.7940
# epoch082:loss0.1133,trainAcc1.0000,ValAcc:0.7900
# epoch083:loss0.1135,trainAcc1.0000,ValAcc:0.8000
# epoch084:loss0.1161,trainAcc1.0000,ValAcc:0.7920
# epoch085:loss0.1160,trainAcc1.0000,ValAcc:0.7940
# epoch086:loss0.1143,trainAcc1.0000,ValAcc:0.8040
# epoch087:loss0.1152,trainAcc1.0000,ValAcc:0.7960
# epoch088:loss0.1163,trainAcc1.0000,ValAcc:0.7940
# epoch089:loss0.1146,trainAcc1.0000,ValAcc:0.7980
# epoch090:loss0.1139,trainAcc1.0000,ValAcc:0.7920
# epoch091:loss0.1151,trainAcc1.0000,ValAcc:0.7960
# epoch092:loss0.1149,trainAcc1.0000,ValAcc:0.7940
# epoch093:loss0.1142,trainAcc1.0000,ValAcc:0.7980
# epoch094:loss0.1150,trainAcc1.0000,ValAcc:0.7940
# epoch095:loss0.1157,trainAcc1.0000,ValAcc:0.7980
# epoch096:loss0.1152,trainAcc1.0000,ValAcc:0.7940
# epoch097:loss0.1152,trainAcc1.0000,ValAcc:0.7980
# epoch098:loss0.1158,trainAcc1.0000,ValAcc:0.7880
# epoch099:loss0.1157,trainAcc1.0000,ValAcc:0.8020
# epoch100:loss0.1153,trainAcc1.0000,ValAcc:0.8000
# epoch101:loss0.1155,trainAcc1.0000,ValAcc:0.7980
# epoch102:loss0.1160,trainAcc1.0000,ValAcc:0.7960
# epoch103:loss0.1160,trainAcc1.0000,ValAcc:0.8020
# epoch104:loss0.1161,trainAcc1.0000,ValAcc:0.7960
# epoch105:loss0.1168,trainAcc1.0000,ValAcc:0.8020
# epoch106:loss0.1170,trainAcc1.0000,ValAcc:0.7920
# epoch107:loss0.1167,trainAcc1.0000,ValAcc:0.7960
# epoch108:loss0.1159,trainAcc1.0000,ValAcc:0.7960
# epoch109:loss0.1150,trainAcc1.0000,ValAcc:0.7960
# epoch110:loss0.1144,trainAcc1.0000,ValAcc:0.8000
# epoch111:loss0.1144,trainAcc1.0000,ValAcc:0.7940
# epoch112:loss0.1155,trainAcc1.0000,ValAcc:0.8000
# epoch113:loss0.1168,trainAcc1.0000,ValAcc:0.7920
# epoch114:loss0.1174,trainAcc1.0000,ValAcc:0.7980
# epoch115:loss0.1173,trainAcc1.0000,ValAcc:0.7900
# epoch116:loss0.1166,trainAcc1.0000,ValAcc:0.8060
# epoch117:loss0.1155,trainAcc1.0000,ValAcc:0.7880
# epoch118:loss0.1146,trainAcc1.0000,ValAcc:0.8000
# epoch119:loss0.1144,trainAcc1.0000,ValAcc:0.8060
# epoch120:loss0.1152,trainAcc1.0000,ValAcc:0.7860
# epoch121:loss0.1161,trainAcc1.0000,ValAcc:0.8080
# epoch122:loss0.1166,trainAcc1.0000,ValAcc:0.7920
# epoch123:loss0.1166,trainAcc1.0000,ValAcc:0.8000
# epoch124:loss0.1162,trainAcc1.0000,ValAcc:0.7940
# epoch125:loss0.1156,trainAcc1.0000,ValAcc:0.8020
# epoch126:loss0.1151,trainAcc1.0000,ValAcc:0.7980
# epoch127:loss0.1148,trainAcc1.0000,ValAcc:0.7940
# epoch128:loss0.1151,trainAcc1.0000,ValAcc:0.8020
# epoch129:loss0.1156,trainAcc1.0000,ValAcc:0.7920
# epoch130:loss0.1161,trainAcc1.0000,ValAcc:0.8000
# epoch131:loss0.1164,trainAcc1.0000,ValAcc:0.7920
# epoch132:loss0.1163,trainAcc1.0000,ValAcc:0.8060
# epoch133:loss0.1160,trainAcc1.0000,ValAcc:0.7880
# epoch134:loss0.1156,trainAcc1.0000,ValAcc:0.8080
# epoch135:loss0.1150,trainAcc1.0000,ValAcc:0.7920
# epoch136:loss0.1147,trainAcc1.0000,ValAcc:0.7980
# epoch137:loss0.1148,trainAcc1.0000,ValAcc:0.8000
# epoch138:loss0.1152,trainAcc1.0000,ValAcc:0.7880
# epoch139:loss0.1156,trainAcc1.0000,ValAcc:0.8060
# epoch140:loss0.1160,trainAcc1.0000,ValAcc:0.7880
# epoch141:loss0.1162,trainAcc1.0000,ValAcc:0.8040
# epoch142:loss0.1163,trainAcc1.0000,ValAcc:0.7900
# epoch143:loss0.1162,trainAcc1.0000,ValAcc:0.7980
# epoch144:loss0.1161,trainAcc1.0000,ValAcc:0.7920
# epoch145:loss0.1157,trainAcc1.0000,ValAcc:0.8000
# epoch146:loss0.1152,trainAcc1.0000,ValAcc:0.7920
# epoch147:loss0.1147,trainAcc1.0000,ValAcc:0.8000
# epoch148:loss0.1145,trainAcc1.0000,ValAcc:0.7940
# epoch149:loss0.1147,trainAcc1.0000,ValAcc:0.7960
# epoch150:loss0.1152,trainAcc1.0000,ValAcc:0.8000
# epoch151:loss0.1158,trainAcc1.0000,ValAcc:0.7920
# epoch152:loss0.1163,trainAcc1.0000,ValAcc:0.7980
# epoch153:loss0.1167,trainAcc1.0000,ValAcc:0.7920
# epoch154:loss0.1170,trainAcc1.0000,ValAcc:0.7980
# epoch155:loss0.1171,trainAcc1.0000,ValAcc:0.7920
# epoch156:loss0.1168,trainAcc1.0000,ValAcc:0.8020
# epoch157:loss0.1158,trainAcc1.0000,ValAcc:0.7880
# epoch158:loss0.1143,trainAcc1.0000,ValAcc:0.8000
# epoch159:loss0.1135,trainAcc1.0000,ValAcc:0.7980
# epoch160:loss0.1141,trainAcc1.0000,ValAcc:0.7920
# epoch161:loss0.1156,trainAcc1.0000,ValAcc:0.8020
# epoch162:loss0.1170,trainAcc1.0000,ValAcc:0.7900
# epoch163:loss0.1176,trainAcc1.0000,ValAcc:0.7980
# epoch164:loss0.1173,trainAcc1.0000,ValAcc:0.7900
# epoch165:loss0.1162,trainAcc1.0000,ValAcc:0.8000
# epoch166:loss0.1146,trainAcc1.0000,ValAcc:0.7940
# epoch167:loss0.1137,trainAcc1.0000,ValAcc:0.7900
# epoch168:loss0.1141,trainAcc1.0000,ValAcc:0.8060
# epoch169:loss0.1153,trainAcc1.0000,ValAcc:0.7860
# epoch170:loss0.1164,trainAcc1.0000,ValAcc:0.8020
# epoch171:loss0.1169,trainAcc1.0000,ValAcc:0.7900
# epoch172:loss0.1165,trainAcc1.0000,ValAcc:0.7980
# epoch173:loss0.1155,trainAcc1.0000,ValAcc:0.7940
# epoch174:loss0.1146,trainAcc1.0000,ValAcc:0.7920
# epoch175:loss0.1144,trainAcc1.0000,ValAcc:0.8000
# epoch176:loss0.1148,trainAcc1.0000,ValAcc:0.7880
# epoch177:loss0.1155,trainAcc1.0000,ValAcc:0.8060
# epoch178:loss0.1159,trainAcc1.0000,ValAcc:0.7860
# epoch179:loss0.1159,trainAcc1.0000,ValAcc:0.8040
# epoch180:loss0.1156,trainAcc1.0000,ValAcc:0.7920
# epoch181:loss0.1151,trainAcc1.0000,ValAcc:0.7960
# epoch182:loss0.1148,trainAcc1.0000,ValAcc:0.7960
# epoch183:loss0.1147,trainAcc1.0000,ValAcc:0.7900
# epoch184:loss0.1150,trainAcc1.0000,ValAcc:0.7960
# epoch185:loss0.1152,trainAcc1.0000,ValAcc:0.7880
# epoch186:loss0.1155,trainAcc1.0000,ValAcc:0.7960
# epoch187:loss0.1156,trainAcc1.0000,ValAcc:0.7860
# epoch188:loss0.1155,trainAcc1.0000,ValAcc:0.7960
# epoch189:loss0.1151,trainAcc1.0000,ValAcc:0.7880
# epoch190:loss0.1149,trainAcc1.0000,ValAcc:0.8000
# epoch191:loss0.1146,trainAcc1.0000,ValAcc:0.7960
# epoch192:loss0.1147,trainAcc1.0000,ValAcc:0.7940
# epoch193:loss0.1149,trainAcc1.0000,ValAcc:0.8000
# epoch194:loss0.1152,trainAcc1.0000,ValAcc:0.7900
# epoch195:loss0.1154,trainAcc1.0000,ValAcc:0.7960
# epoch196:loss0.1155,trainAcc1.0000,ValAcc:0.7880
# epoch197:loss0.1156,trainAcc1.0000,ValAcc:0.7940
# epoch198:loss0.1155,trainAcc1.0000,ValAcc:0.7880
# epoch199:loss0.1155,trainAcc1.0000,ValAcc:0.7900
# test accuarcy 0.815000057220459

# %%
plot_loss_with_acc(loss,val_acc)

# %%
#绘制TSNE降维图
from sklearn.manifold import TSNE
tsne=TSNE()
out=tsne.fit_transform(test_logits)
fig=plt.figure()
for i in range(7):
    indices=test_label=i
    x,y=out[indices].T
    plt.scatter(x,y,label=str(i))
plt.legend()
